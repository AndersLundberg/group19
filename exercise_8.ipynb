# %% [markdown]
# # Exercise Set 8: Introduction to Web Scraping
#
# *Afternoon, August 16, 2018*
#
# In this Exercise Set we shall practice our webscraping skills utiilizing only basic python. We shall cover variations between static and dynamic pages.

# %% [markdown]
# ## Exercise Section 8.1: Scraping Jobnet.dk
#
# This exercise you get to practice locating the request that the JavaScript sends to get the job data that it builds the joblistings from. You should use the **>Network Monitor<** tool in your browser.
#
# Furthermore you practice spotting how the pagination is done, without clicking on the next page button, but instead changing a small parameter in the URL.

# %% [markdown]
# > **Ex. 8.1.1:** Hit the joblisting webpage here: https://job.jobnet.dk/CV and locate the request that gets the joblisting data using the a tool called the **>Network Monitor<**. To do this open monitor tool and press the search button on the website. Go to the _network_ pane in the monitor and look at the results. Which two _methods_ does your browser use to communicate with the webserver? What does status code 200 mean?
# >
# >> _Hint:_ The network monitor is launched by pressing ctrl+shift+i in most browsers. Filter by XHR files.

# %%
# [Answer to Ex. 8.1.1 here]

#200 it went well with the requests

import requests
#response = requests.get('https://www.google.com')
session = requests.session()
session.headers['email'] = 'youremail' 
session.headers['name'] = 'name'
#session.headers['User-Agent'] = '' # sometimes you need to pose as another agent...
session.headers

# Control the pace of your calls
import time
def ratelimit():
    "A function that handles the rate of your calls."
    time.sleep(1) # sleep one second.
# Reliable requests
def get(url,iterations=10,check_function=lambda x: x.ok):
    """This module ensures that your script does not crash from connection errors.
        that you limit the rate of your calls
        that you have some reliability check
        iterations : Define number of iterations before giving up. 
        exceptions: Define which exceptions you accept, default is all. 
    """
    for iteration in range(iterations):
        try:
            # add ratelimit function call here
            ratelimit() # !!
            response = session.get(url)
            if check_function(response):
                return response # if succesful it will end the iterations here
        except exceptions as e: #  find exceptions in the request library requests.exceptions
            print(e) # print or log the exception message.
    return None # your code will purposely crash if you don't create a check function later.

# %% [markdown]
# > **Ex. 8.1.2.:** Use the `request` module to collect the first page of job postings and unpack the relevant `json` data into a `pandas` DataFrame.

# %%
# [Answer to Ex. 8.1.2 here]
#https://job.jobnet.dk/CV/FindWork/Search

#https://job.jobnet.dk/CV/FindWork?Offset=60&SortValue=BestMatch

import requests
import json
import pandas as pd

response = requests.get('https://job.jobnet.dk/CV/FindWork/Search?Offset=0&SortValue=BestMatch')
response.ok
d=json.loads(response.text)

print(type(d))
print(d.keys())

df=pd.DataFrame(d['JobPositionPostings'])
print(df.head(5))
# Out:
# <class 'dict'>
# dict_keys(['Expression', 'Facets', 'JobPositionPostings', 'TotalResultCount'])
#    AnonymousEmployer  AssignmentStartDate  AutomatchType  Country  \
# 0              False  0001-01-01T00:00:00              0  Danmark
# 1              False  0001-01-01T00:00:00              0  Danmark
# 2              False  0001-01-01T00:00:00              0  Danmark
# 3              False  0001-01-01T00:00:00              0  Danmark
# 4              False  0001-01-01T00:00:00              0  Danmark
#
#   EmploymentType  HasLocationValues  HiringOrgCVR  \
# 0                              True      55133018
# 1                              True      55133018
# 2                              True      55133018
# 3                              True      36468939
# 4                              True      36468939
#
#                                        HiringOrgName       ID  IsExternal  \
# 0  Myndighedsafdeling, Socialcenter for Voksne, V...  4859374       False
# 1                       INTEGRERET INSTITUTION SOLEN  4865269       False
# 2  Dagtilbud Hasle - 4151 afd. Børnehaven Charlot...  4865265       False
# 3                                  JP KRISTENSEN ApS  4839655       False
# 4                                  JP KRISTENSEN ApS  4841050       False
#
#       ...      UseWorkPlaceAddressForJoblog Weight WorkHours WorkPlaceAbroad  \
# 0     ...                              True    1.0   Fuldtid           False
# 1     ...                              True    1.0   Fuldtid           False
# 2     ...                              True    1.0   Fuldtid           False
# 3     ...                             False    1.0   Fuldtid           False
# 4     ...                             False    1.0   Fuldtid           False
#
#   WorkPlaceAddress WorkPlaceCity  WorkPlaceNotStatic WorkPlaceOtherAddress  \
# 0    Grøndalsvej 1        Viby J               False                 False
# 1  Kappelvænget 46      Aarhus V               False                 False
# 2   Bornholmsvej 9      Aarhus V               False                 False
# 3                                              False                  True
# 4                                              False                  True
#
#    WorkPlacePostalCode WorkplaceID
# 0                 8260      113631
# 1                 8210       30425
# 2                 8210      128212
# 3                           113456
# 4                           113456
#
# [5 rows x 42 columns]

# %% [markdown]
# > **Ex. 8.1.3.:** Store and print the 'TotalResultCount' value for later use. Also create a dataframe from the 'JobPositionPostings' field in the json.

# %%
# [Answer to Ex. 8.1.3 here]
total_res=(d['TotalResultCount'])
total_res #16008
# Out:
# 16008

# %% [markdown]
# > **Ex. 8.1.4:** This exercise is about paging the results. We need to understand the websites pagination scheme. Scroll down the webpage and press the next page button. Describe how the parameters of the url changes as you turn the pages.

# %%
# [Answer to Ex. 8.1.4 here]
#they change by 20, so 
##https://job.jobnet.dk/CV/FindWork?Offset=0&SortValue=BestMatch
##https://job.jobnet.dk/CV/FindWork?Offset=20&SortValue=BestMatch
##https://job.jobnet.dk/CV/FindWork?Offset=40&SortValue=BestMatch
##https://job.jobnet.dk/CV/FindWork?Offset=60&SortValue=BestMatch

# %% [markdown]
# > **Ex. 8.1.5:** Design a`for` loop using the `range` function that changes this paging parameter in the URL. Use the TotalResultCount parameter from before to define the limits of the range function. Store these urls in a container.
# >
# >**Bonus** Change the SortValue parameter from BestMatch to CreationDate, to make the sorting amendable to updating results daily.
# >
# >> _Hint:_ See that the parameter is an offset and that this relates to the number of results pr. call made.

# %%
# [Answer to Ex. 8.1.5 here]
links=[]

for i in range(0,(total_res//20)):
    links.append('https://job.jobnet.dk/CV/FindWork/Search?Offset='+ str(i*20)+'&SortValue=BestMatch')
    
links
# Out:
# ['https://job.jobnet.dk/CV/FindWork/Search?Offset=0&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=20&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=40&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=60&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=80&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=100&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=120&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=140&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=160&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=180&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=200&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=220&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=240&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=260&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=280&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=300&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=320&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=340&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=360&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=380&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=400&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=420&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=440&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=460&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=480&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=500&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=520&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=540&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=560&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=580&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=600&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=620&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=640&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=660&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=680&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=700&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=720&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=740&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=760&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=780&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=800&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=820&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=840&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=860&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=880&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=900&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=920&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=940&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=960&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=980&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1000&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1020&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1040&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1060&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1080&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1100&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1120&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1140&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1160&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1180&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1200&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1220&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1240&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1260&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1280&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1300&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1320&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1340&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1360&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1380&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1400&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1420&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1440&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1460&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1480&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1500&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1520&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1540&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1560&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1580&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1600&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1620&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1640&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1660&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1680&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1700&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1720&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1740&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1760&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1780&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1800&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1820&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1840&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1860&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1880&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1900&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1920&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1940&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1960&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=1980&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2000&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2020&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2040&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2060&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2080&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2100&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2120&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2140&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2160&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2180&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2200&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2220&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2240&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2260&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2280&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2300&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2320&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2340&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2360&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2380&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2400&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2420&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2440&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=2460&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset
SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=15960&SortValue=BestMatch',
#  'https://job.jobnet.dk/CV/FindWork/Search?Offset=15980&SortValue=BestMatch']

# %% [markdown]
# > **Ex. 8.1.6:** Pick 20 random links using the `choice` function in the `random` module;  collect the links using the `request` module. Also use the `time.sleep()` function to limit the rate of your calls. Make sure to save the links already collected in a `set()` container to avoid having to reload links already collected. ***extra***: monitor the time left to completing the loop by using `tqdm.tqdm()` function.

# %%
# [Answer to Ex. 8.1.6 here]
import random
import time
urls=random.sample(links,20)
a

done=set()

for url in urls:
#    time.sleep(1)
    response=requests.get(url)
    if not (response.ok) :
        print("It didn't go as planned")
    else :
        done.add(url)
# Out:
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned
# It didn't go as planned

# %% [markdown]
# > **Ex. 8.1.7:** Load all the results into a DataFrame.

# %%
# [Answer to Ex. 8.1.7 here]

# %% [markdown]
# ## Exercise Section 8.2: Scraping Trustpilot.com
# Now for a slightly more elaborate, yet still simple scraping problem. Here we want to scrape trustpilot for user reviews. This data is very nice since it provides free labeled data (rating) to train a machine learning model to understand positive and negative sentiment.
#
# Here you will practice crawling a website collecting the links to each company review page, and finally locate another behind the scenes JavaScript request that gets the review data in a neat json format.

# %% [markdown]
# > **Ex. 8.2.1:** Visit the https://www.trustpilot.com/ website and locate the categories page. From this page you find links to company listings. Get the category page using the `requests` module and extract each link to a specific category page from the HTML. This can be done using the basic python `.split()` string method. Make sure only links within the ***/categories/*** section are kept, checking each string using the ```if 'pattern' in string``` condition.
# >
# >> *Hint:* The links are relative. You need to add the domain name
# >>
# >> *Hint #2:* You will need to convert the page response to a string, using the `.text` property.

# %%
# [Answer to Ex. 8.2.1]

# %% [markdown]
# > **Ex. 8.2.2:** Get one of the category section links (any one will do). Write a function to extract the links to the company review pages from the HTML.

# %%
# [Answer to Ex. 8.2.2]

# %% [markdown]
# > **Ex. 8.2.3:** Figure out how the pagination is done, by following how the url changes when pressing the **next page**-button to obtain more company listings. Write a function that builds links to paging all the company listing results of each category. This includes parsing the number of subpages of each category and changing the correct parameter in the url.
# >
# >> *Hint:* Find the maximum number of result pages, right before the next page button and make a loop change the page parameter of the url.

# %%
# [Answer to Ex.8.2.3]

# %% [markdown]
# > **Ex. 8.2.4:** Loop through all categories and build the paging links using the above defined function.

# %%
# [Answer to Ex.8.2.4]

# %% [markdown]
# > **Ex. 8.2.5:** Randomly pick one of category listing links you have generated, and get the links to the companies listed using the other function defined.

# %%
# [Answer to Ex.8.2.5]

# %% [markdown]
# > **Ex. 8.2.6:** Visit one of these links and inspect the **>Network Monitor<** to locate the request that loads the review data. Use the requests module to retrieve this link and unpack the json results to a pandas DataFrame.
# >
# >> _Hint:_ Look for a request which sends a the link to a file called `jsonId`

# %%
#[Answer to Ex.8.2.6]

# %% [markdown]
# Congratulations on coming this far. By now you are almost - still need to figure out how to page the reviews and to find the company ID in the html -, ready to deploy a scraper collecting all reviews on trustpilot.
# If you wanna see just how valuable such data could be visit the follow blogpost: https://blog.openai.com/unsupervised-sentiment-neuron/
